# %%
import numpy as np
import pandas as pd

# %%
df_random_sig3 = pd.read_csv('df_random_σ=0.01.csv')
df_baseline_sig3_eps1 = pd.read_csv('df_baseline_σ=0.01_ε=0.1.csv')
df_baseline_sig3_eps2 = pd.read_csv('df_baseline_σ=0.01_ε=0.2.csv')
df_baseline_sig3_eps3 = pd.read_csv('df_baseline_σ=0.01_ε=0.3.csv')
df_egreedy_sig3_eps1 = pd.read_csv('df_egreedy_σ=0.01_ε=0.1.csv')
df_egreedy_sig3_eps2 = pd.read_csv('df_egreedy_σ=0.01_ε=0.2.csv')
df_egreedy_sig3_eps3 = pd.read_csv('df_egreedy_σ=0.01_ε=0.3.csv')
df_edecay_sig3_eps1_d99 = pd.read_csv('df_egreedy_σ=0.01_ε=0.1_λ=0.99.csv')
df_edecay_sig3_eps1_d95 = pd.read_csv('df_egreedy_σ=0.01_ε=0.1_λ=0.95.csv')
df_edecay_sig3_eps1_d90 = pd.read_csv('df_egreedy_σ=0.01_ε=0.1_λ=0.90.csv')
df_edecay_sig3_eps2_d99 = pd.read_csv('df_egreedy_σ=0.01_ε=0.2_λ=0.99.csv')
df_edecay_sig3_eps2_d95 = pd.read_csv('df_egreedy_σ=0.01_ε=0.2_λ=0.95.csv')
df_edecay_sig3_eps2_d90 = pd.read_csv('df_egreedy_σ=0.01_ε=0.2_λ=0.90.csv')
df_edecay_sig3_eps3_d99 = pd.read_csv('df_egreedy_σ=0.01_ε=0.3_λ=0.99.csv')
df_edecay_sig3_eps3_d95 = pd.read_csv('df_egreedy_σ=0.01_ε=0.3_λ=0.95.csv')
df_edecay_sig3_eps3_d90 = pd.read_csv('df_egreedy_σ=0.01_ε=0.3_λ=0.90.csv')

# %%
av_df_random_sig3 = df_random_sig3['total runs average rewards'][49]
av_df_baseline_sig3_eps1 = df_baseline_sig3_eps1['total runs average rewards'][48]
av_df_baseline_sig3_eps2 = df_baseline_sig3_eps2['total runs average rewards'][48]
av_df_baseline_sig3_eps3 = df_baseline_sig3_eps3['total runs average rewards'][48]
av_df_egreedy_sig3_eps1 = df_egreedy_sig3_eps1['total runs average rewards'][48]
av_df_egreedy_sig3_eps2 = df_egreedy_sig3_eps2['total runs average rewards'][48]
av_df_egreedy_sig3_eps3 = df_egreedy_sig3_eps3['total runs average rewards'][48]
av_df_edecay_sig3_eps1_d99 = df_edecay_sig3_eps1_d99['total runs average rewards'][48]
av_df_edecay_sig3_eps1_d95 = df_edecay_sig3_eps1_d95['total runs average rewards'][48]
av_df_edecay_sig3_eps1_d90 = df_edecay_sig3_eps1_d90['total runs average rewards'][48]
av_df_edecay_sig3_eps2_d99 = df_edecay_sig3_eps2_d99['total runs average rewards'][48]
av_df_edecay_sig3_eps2_d95 = df_edecay_sig3_eps2_d95['total runs average rewards'][48]
av_df_edecay_sig3_eps2_d90 = df_edecay_sig3_eps2_d90['total runs average rewards'][48]
av_df_edecay_sig3_eps3_d99 = df_edecay_sig3_eps3_d99['total runs average rewards'][48]
av_df_edecay_sig3_eps3_d95 = df_edecay_sig3_eps3_d95['total runs average rewards'][48]
av_df_edecay_sig3_eps3_d90 = df_edecay_sig3_eps3_d90['total runs average rewards'][48]

# %%
cum_df_random_sig3 = df_random_sig3['total runs cum rewards'][49]
cum_df_baseline_sig3_eps1 = df_baseline_sig3_eps1['total runs cum rewards'][48]
cum_df_baseline_sig3_eps2 = df_baseline_sig3_eps2['total runs cum rewards'][48]
cum_df_baseline_sig3_eps3 = df_baseline_sig3_eps3['total runs cum rewards'][48]
cum_df_egreedy_sig3_eps1 = df_egreedy_sig3_eps1['total runs cum rewards'][48]
cum_df_egreedy_sig3_eps2 = df_egreedy_sig3_eps2['total runs cum rewards'][48]
cum_df_egreedy_sig3_eps3 = df_egreedy_sig3_eps3['total runs cum rewards'][48]
cum_df_edecay_sig3_eps1_d99 = df_edecay_sig3_eps1_d99['total runs cum rewards'][48]
cum_df_edecay_sig3_eps1_d95 = df_edecay_sig3_eps1_d95['total runs cum rewards'][48]
cum_df_edecay_sig3_eps1_d90 = df_edecay_sig3_eps1_d90['total runs cum rewards'][48]
cum_df_edecay_sig3_eps2_d99 = df_edecay_sig3_eps2_d99['total runs cum rewards'][48]
cum_df_edecay_sig3_eps2_d95 = df_edecay_sig3_eps2_d95['total runs cum rewards'][48]
cum_df_edecay_sig3_eps2_d90 = df_edecay_sig3_eps2_d90['total runs cum rewards'][48]
cum_df_edecay_sig3_eps3_d99 = df_edecay_sig3_eps3_d99['total runs cum rewards'][48]
cum_df_edecay_sig3_eps3_d95 = df_edecay_sig3_eps3_d95['total runs cum rewards'][48]
cum_df_edecay_sig3_eps3_d90 = df_edecay_sig3_eps3_d90['total runs cum rewards'][48]

# %%
av_sig_3 = {"df_random_sig3":av_df_random_sig3,
        "df_baseline_sig3_eps1":av_df_baseline_sig3_eps1,
       "df_baseline_sig3_eps2":av_df_baseline_sig3_eps2,
       "df_baseline_sig3_eps3":av_df_baseline_sig3_eps3,
       "df_egreedy_sig3_eps1":av_df_egreedy_sig3_eps1,
       "df_egreedy_sig3_eps2":av_df_egreedy_sig3_eps2,
       "df_egreedy_sig3_eps3":av_df_egreedy_sig3_eps3,
       "df_edecay_sig3_eps1_d99":av_df_edecay_sig3_eps1_d99,
       "df_edecay_sig3_eps1_d95":av_df_edecay_sig3_eps1_d95,
       "df_edecay_sig3_eps1_d90":av_df_edecay_sig3_eps1_d90,
       "df_edecay_sig3_eps2_d99":av_df_edecay_sig3_eps2_d99,
       "df_edecay_sig3_eps2_d95":av_df_edecay_sig3_eps2_d95,
       "df_edecay_sig3_eps2_d90":av_df_edecay_sig3_eps2_d90,
       "df_edecay_sig3_eps3_d99":av_df_edecay_sig3_eps3_d99,
       "df_edecay_sig3_eps3_d95":av_df_edecay_sig3_eps3_d95,
       "df_edecay_sig3_eps3_d90":av_df_edecay_sig3_eps3_d90}

# %%
average_sig3 = pd.DataFrame({'Model': list(av_sig_3.keys()), 'Average': list(av_sig_3.values())})

# %%
cum_sig_3 = {"df_random_sig3":cum_df_random_sig3,
        "df_baseline_sig3_eps1":cum_df_baseline_sig3_eps1,
       "df_baseline_sig3_eps2":cum_df_baseline_sig3_eps2,
       "df_baseline_sig3_eps3":cum_df_baseline_sig3_eps3,
       "df_egreedy_sig3_eps1":cum_df_egreedy_sig3_eps1,
       "df_egreedy_sig3_eps2":cum_df_egreedy_sig3_eps2,
       "df_egreedy_sig3_eps3":cum_df_egreedy_sig3_eps3,
       "df_edecay_sig3_eps1_d99":cum_df_edecay_sig3_eps1_d99,
       "df_edecay_sig3_eps1_d95":cum_df_edecay_sig3_eps1_d95,
       "df_edecay_sig3_eps1_d90":cum_df_edecay_sig3_eps1_d90,
       "df_edecay_sig3_eps2_d99":cum_df_edecay_sig3_eps2_d99,
       "df_edecay_sig3_eps2_d95":cum_df_edecay_sig3_eps2_d95,
       "df_edecay_sig3_eps2_d90":cum_df_edecay_sig3_eps2_d90,
       "df_edecay_sig3_eps3_d99":cum_df_edecay_sig3_eps3_d99,
       "df_edecay_sig3_eps3_d95":cum_df_edecay_sig3_eps3_d95,
       "df_edecay_sig3_eps3_d90":cum_df_edecay_sig3_eps3_d90}

# %%
cumul_sig3 = pd.DataFrame({'Model': list(cum_sig_3.keys()), 'Cum': list(cum_sig_3.values())})

# %%
sig3 = average_sig3.merge(cumul_sig3,on='Model')
sig3
# Out:
#                       Model   Average      Cum
# 0            df_random_sig3  0.038365  1.87989
# 1     df_baseline_sig3_eps1  0.041178  2.01773
# 2     df_baseline_sig3_eps2  0.040924  2.00528
# 3     df_baseline_sig3_eps3  0.040595  1.98915
# 4      df_egreedy_sig3_eps1  0.043938  2.15295
# 5      df_egreedy_sig3_eps2  0.043311  2.12223
# 6      df_egreedy_sig3_eps3  0.042260  2.07074
# 7   df_edecay_sig3_eps1_d99  0.042305  2.07296
# 8   df_edecay_sig3_eps1_d95  0.042799  2.09717
# 9   df_edecay_sig3_eps1_d90  0.042459  2.08049
# 10  df_edecay_sig3_eps2_d99  0.042463  2.08067
# 11  df_edecay_sig3_eps2_d95  0.042028  2.05938
# 12  df_edecay_sig3_eps2_d90  0.042744  2.09446
# 13  df_edecay_sig3_eps3_d99  0.042044  2.06015
# 14  df_edecay_sig3_eps3_d95  0.041870  2.05163
# 15  df_edecay_sig3_eps3_d90  0.043726  2.14259

# %%
sig3.to_csv('SIG3.csv')

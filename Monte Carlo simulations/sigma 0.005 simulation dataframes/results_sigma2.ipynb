# %%
import numpy as np
import pandas as pd

# %%
df_random_sig2 = pd.read_csv('df_random_σ=0.005.csv')
df_baseline_sig2_eps1 = pd.read_csv('df_baseline_σ=0.005_ε=0.1.csv')
df_baseline_sig2_eps2 = pd.read_csv('df_baseline_σ=0.005_ε=0.2.csv')
df_baseline_sig2_eps3 = pd.read_csv('df_baseline_σ=0.005_ε=0.3.csv')
df_egreedy_sig2_eps1 = pd.read_csv('df_egreedy_σ=0.005_ε=0.1.csv')
df_egreedy_sig2_eps2 = pd.read_csv('df_egreedy_σ=0.005_ε=0.2.csv')
df_egreedy_sig2_eps3 = pd.read_csv('df_egreedy_σ=0.005_ε=0.3.csv')
df_edecay_sig2_eps1_d99 = pd.read_csv('df_egreedy_σ=0.005_ε=0.1_λ=0.99.csv')
df_edecay_sig2_eps1_d95 = pd.read_csv('df_egreedy_σ=0.005_ε=0.1_λ=0.95.csv')
df_edecay_sig2_eps1_d90 = pd.read_csv('df_egreedy_σ=0.005_ε=0.1_λ=0.90.csv')
df_edecay_sig2_eps2_d99 = pd.read_csv('df_egreedy_σ=0.005_ε=0.2_λ=0.99.csv')
df_edecay_sig2_eps2_d95 = pd.read_csv('df_egreedy_σ=0.005_ε=0.2_λ=0.95.csv')
df_edecay_sig2_eps2_d90 = pd.read_csv('df_egreedy_σ=0.005_ε=0.2_λ=0.90.csv')
df_edecay_sig2_eps3_d99 = pd.read_csv('df_egreedy_σ=0.005_ε=0.3_λ=0.99.csv')
df_edecay_sig2_eps3_d95 = pd.read_csv('df_egreedy_σ=0.005_ε=0.3_λ=0.95.csv')
df_edecay_sig2_eps3_d90 = pd.read_csv('df_egreedy_σ=0.005_ε=0.3_λ=0.90.csv')

# %%
av_df_random_sig2 = df_random_sig2['total runs average rewards'][50]
av_df_baseline_sig2_eps1 = df_baseline_sig2_eps1['total runs average rewards'][49]
av_df_baseline_sig2_eps2 = df_baseline_sig2_eps2['total runs average rewards'][49]
av_df_baseline_sig2_eps3 = df_baseline_sig2_eps3['total runs average rewards'][49]
av_df_egreedy_sig2_eps1 = df_egreedy_sig2_eps1['total runs average rewards'][49]
av_df_egreedy_sig2_eps2 = df_egreedy_sig2_eps2['total runs average rewards'][49]
av_df_egreedy_sig2_eps3 = df_egreedy_sig2_eps3['total runs average rewards'][49]
av_df_edecay_sig2_eps1_d99 = df_edecay_sig2_eps1_d99['total runs average rewards'][49]
av_df_edecay_sig2_eps1_d95 = df_edecay_sig2_eps1_d95['total runs average rewards'][49]
av_df_edecay_sig2_eps1_d90 = df_edecay_sig2_eps1_d90['total runs average rewards'][49]
av_df_edecay_sig2_eps2_d99 = df_edecay_sig2_eps2_d99['total runs average rewards'][49]
av_df_edecay_sig2_eps2_d95 = df_edecay_sig2_eps2_d95['total runs average rewards'][49]
av_df_edecay_sig2_eps2_d90 = df_edecay_sig2_eps2_d90['total runs average rewards'][49]
av_df_edecay_sig2_eps3_d99 = df_edecay_sig2_eps3_d99['total runs average rewards'][49]
av_df_edecay_sig2_eps3_d95 = df_edecay_sig2_eps3_d95['total runs average rewards'][49]
av_df_edecay_sig2_eps3_d90 = df_edecay_sig2_eps3_d90['total runs average rewards'][49]

# %%
cum_df_random_sig2 = df_random_sig2['total runs cum rewards'][50]
cum_df_baseline_sig2_eps1 = df_baseline_sig2_eps1['total runs cum rewards'][49]
cum_df_baseline_sig2_eps2 = df_baseline_sig2_eps2['total runs cum rewards'][49]
cum_df_baseline_sig2_eps3 = df_baseline_sig2_eps3['total runs cum rewards'][49]
cum_df_egreedy_sig2_eps1 = df_egreedy_sig2_eps1['total runs cum rewards'][49]
cum_df_egreedy_sig2_eps2 = df_egreedy_sig2_eps2['total runs cum rewards'][49]
cum_df_egreedy_sig2_eps3 = df_egreedy_sig2_eps3['total runs cum rewards'][49]
cum_df_edecay_sig2_eps1_d99 = df_edecay_sig2_eps1_d99['total runs cum rewards'][49]
cum_df_edecay_sig2_eps1_d95 = df_edecay_sig2_eps1_d95['total runs cum rewards'][49]
cum_df_edecay_sig2_eps1_d90 = df_edecay_sig2_eps1_d90['total runs cum rewards'][49]
cum_df_edecay_sig2_eps2_d99 = df_edecay_sig2_eps2_d99['total runs cum rewards'][49]
cum_df_edecay_sig2_eps2_d95 = df_edecay_sig2_eps2_d95['total runs cum rewards'][49]
cum_df_edecay_sig2_eps2_d90 = df_edecay_sig2_eps2_d90['total runs cum rewards'][49]
cum_df_edecay_sig2_eps3_d99 = df_edecay_sig2_eps3_d99['total runs cum rewards'][49]
cum_df_edecay_sig2_eps3_d95 = df_edecay_sig2_eps3_d95['total runs cum rewards'][49]
cum_df_edecay_sig2_eps3_d90 = df_edecay_sig2_eps3_d90['total runs cum rewards'][49]

# %%
av_sig_2 = {"df_random_sig2":av_df_random_sig2,
        "df_baseline_sig2_eps1":av_df_baseline_sig2_eps1,
       "df_baseline_sig2_eps2":av_df_baseline_sig2_eps2,
       "df_baseline_sig2_eps3":av_df_baseline_sig2_eps3,
       "df_egreedy_sig2_eps1":av_df_egreedy_sig2_eps1,
       "df_egreedy_sig2_eps2":av_df_egreedy_sig2_eps2,
       "df_egreedy_sig2_eps3":av_df_egreedy_sig2_eps3,
       "df_edecay_sig2_eps1_d99":av_df_edecay_sig2_eps1_d99,
       "df_edecay_sig2_eps1_d95":av_df_edecay_sig2_eps1_d95,
       "df_edecay_sig2_eps1_d90":av_df_edecay_sig2_eps1_d90,
       "df_edecay_sig2_eps2_d99":av_df_edecay_sig2_eps2_d99,
       "df_edecay_sig2_eps2_d95":av_df_edecay_sig2_eps2_d95,
       "df_edecay_sig2_eps2_d90":av_df_edecay_sig2_eps2_d90,
       "df_edecay_sig2_eps3_d99":av_df_edecay_sig2_eps3_d99,
       "df_edecay_sig2_eps3_d95":av_df_edecay_sig2_eps3_d95,
       "df_edecay_sig2_eps3_d90":av_df_edecay_sig2_eps3_d90}

# %%
average_sig2 = pd.DataFrame({'Model': list(av_sig_2.keys()), 'Average': list(av_sig_2.values())})

# %%
cum_sig_2 = {"df_random_sig2":cum_df_random_sig2,
        "df_baseline_sig2_eps1":cum_df_baseline_sig2_eps1,
       "df_baseline_sig2_eps2":cum_df_baseline_sig2_eps2,
       "df_baseline_sig2_eps3":cum_df_baseline_sig2_eps3,
       "df_egreedy_sig2_eps1":cum_df_egreedy_sig2_eps1,
       "df_egreedy_sig2_eps2":cum_df_egreedy_sig2_eps2,
       "df_egreedy_sig2_eps3":cum_df_egreedy_sig2_eps3,
       "df_edecay_sig2_eps1_d99":cum_df_edecay_sig2_eps1_d99,
       "df_edecay_sig2_eps1_d95":cum_df_edecay_sig2_eps1_d95,
       "df_edecay_sig2_eps1_d90":cum_df_edecay_sig2_eps1_d90,
       "df_edecay_sig2_eps2_d99":cum_df_edecay_sig2_eps2_d99,
       "df_edecay_sig2_eps2_d95":cum_df_edecay_sig2_eps2_d95,
       "df_edecay_sig2_eps2_d90":cum_df_edecay_sig2_eps2_d90,
       "df_edecay_sig2_eps3_d99":cum_df_edecay_sig2_eps3_d99,
       "df_edecay_sig2_eps3_d95":cum_df_edecay_sig2_eps3_d95,
       "df_edecay_sig2_eps3_d90":cum_df_edecay_sig2_eps3_d90}

# %%
cumul_sig2 = pd.DataFrame({'Model': list(cum_sig_2.keys()), 'Cum': list(cum_sig_2.values())})

# %%
sig2 = average_sig2.merge(cumul_sig2,on='Model')

# %%
sig2
# Out:
#                       Model   Average      Cum
# 0            df_random_sig2  0.046261  2.31304
# 1     df_baseline_sig2_eps1  0.061200  3.05998
# 2     df_baseline_sig2_eps2  0.061292  3.06460
# 3     df_baseline_sig2_eps3  0.059640  2.98201
# 4      df_egreedy_sig2_eps1  0.066704  3.33522
# 5      df_egreedy_sig2_eps2  0.063735  3.18676
# 6      df_egreedy_sig2_eps3  0.061075  3.05376
# 7   df_edecay_sig2_eps1_d99  0.067873  3.39365
# 8   df_edecay_sig2_eps1_d95  0.066262  3.31312
# 9   df_edecay_sig2_eps1_d90  0.067490  3.37450
# 10  df_edecay_sig2_eps2_d99  0.068303  3.41514
# 11  df_edecay_sig2_eps2_d95  0.068403  3.42016
# 12  df_edecay_sig2_eps2_d90  0.068091  3.40456
# 13  df_edecay_sig2_eps3_d99  0.066710  3.33549
# 14  df_edecay_sig2_eps3_d95  0.067136  3.35679
# 15  df_edecay_sig2_eps3_d90  0.068215  3.41076

# %%
sig2.to_csv('SIG2.csv')

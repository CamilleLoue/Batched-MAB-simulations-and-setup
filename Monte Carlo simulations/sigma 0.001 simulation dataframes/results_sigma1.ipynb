# %%
import numpy as np
import pandas as pd

# %%
df_random_sig1 = pd.read_csv('df_random_σ=0.001.csv')
df_baseline_sig1_eps1 = pd.read_csv('df_baseline_σ=0.001_ε=0.1.csv')
df_baseline_sig1_eps2 = pd.read_csv('df_baseline_σ=0.001_ε=0.2.csv')
df_baseline_sig1_eps3 = pd.read_csv('df_baseline_σ=0.001_ε=0.3.csv')
df_egreedy_sig1_eps1 = pd.read_csv('df_egreedy_σ=0.001_ε=0.1.csv')
df_egreedy_sig1_eps2 = pd.read_csv('df_egreedy_σ=0.001_ε=0.2.csv')
df_egreedy_sig1_eps3 = pd.read_csv('df_egreedy_σ=0.001_ε=0.3.csv')
df_edecay_sig1_eps1_d99 = pd.read_csv('df_egreedy_σ=0.001_ε=0.1_λ=0.99.csv')
df_edecay_sig1_eps1_d95 = pd.read_csv('df_egreedy_σ=0.001_ε=0.1_λ=0.95.csv')
df_edecay_sig1_eps1_d90 = pd.read_csv('df_egreedy_σ=0.001_ε=0.1_λ=0.90.csv')
df_edecay_sig1_eps2_d99 = pd.read_csv('df_egreedy_σ=0.001_ε=0.2_λ=0.99.csv')
df_edecay_sig1_eps2_d95 = pd.read_csv('df_egreedy_σ=0.001_ε=0.2_λ=0.95.csv')
df_edecay_sig1_eps2_d90 = pd.read_csv('df_egreedy_σ=0.001_ε=0.2_λ=0.90.csv')
df_edecay_sig1_eps3_d99 = pd.read_csv('df_egreedy_σ=0.001_ε=0.3_λ=0.99.csv')
df_edecay_sig1_eps3_d95 = pd.read_csv('df_egreedy_σ=0.001_ε=0.3_λ=0.95.csv')
df_edecay_sig1_eps3_d90 = pd.read_csv('df_egreedy_σ=0.001_ε=0.3_λ=0.90.csv')

# %%
df_random_sig1
# Out:
#         av_0      av_1      av_2      av_3      av_4      av_5      av_6  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.064600  0.058600  0.060200  0.060100  0.054700  0.059000  0.057900
# 2   0.062050  0.060200  0.059850  0.059250  0.058250  0.057950  0.057950
# 3   0.059600  0.059533  0.059400  0.058900  0.060300  0.058300  0.057900
# 4   0.060175  0.060025  0.060200  0.058475  0.059775  0.058375  0.057800
# 5   0.059720  0.060280  0.059840  0.058620  0.059780  0.059380  0.058220
# 6   0.060033  0.060267  0.059917  0.058483  0.059217  0.059567  0.058583
# 7   0.060271  0.059943  0.059914  0.058571  0.058929  0.059829  0.059286
# 8   0.059888  0.059638  0.060400  0.058412  0.058912  0.059325  0.058775
# 9   0.059878  0.059778  0.060222  0.058644  0.058867  0.059322  0.058800
# 10  0.059720  0.059640  0.060110  0.058610  0.059090  0.059320  0.058570
# 11  0.059682  0.059573  0.059955  0.058718  0.059473  0.058982  0.058436
# ...

# %%
av_df_random_sig1 = df_random_sig1['total runs average rewards'][50]
av_df_baseline_sig1_eps1 = df_baseline_sig1_eps1['total runs average rewards'][49]
av_df_baseline_sig1_eps2 = df_baseline_sig1_eps2['total runs average rewards'][49]
av_df_baseline_sig1_eps3 = df_baseline_sig1_eps3['total runs average rewards'][49]
av_df_egreedy_sig1_eps1 = df_egreedy_sig1_eps1['total runs average rewards'][49]
av_df_egreedy_sig1_eps2 = df_egreedy_sig1_eps2['total runs average rewards'][49]
av_df_egreedy_sig1_eps3 = df_egreedy_sig1_eps3['total runs average rewards'][49]
av_df_edecay_sig1_eps1_d99 = df_edecay_sig1_eps1_d99['total runs average rewards'][49]
av_df_edecay_sig1_eps1_d95 = df_edecay_sig1_eps1_d95['total runs average rewards'][49]
av_df_edecay_sig1_eps1_d90 = df_edecay_sig1_eps1_d90['total runs average rewards'][49]
av_df_edecay_sig1_eps2_d99 = df_edecay_sig1_eps2_d99['total runs average rewards'][49]
av_df_edecay_sig1_eps2_d95 = df_edecay_sig1_eps2_d95['total runs average rewards'][49]
av_df_edecay_sig1_eps2_d90 = df_edecay_sig1_eps2_d90['total runs average rewards'][49]
av_df_edecay_sig1_eps3_d99 = df_edecay_sig1_eps3_d99['total runs average rewards'][49]
av_df_edecay_sig1_eps3_d95 = df_edecay_sig1_eps3_d95['total runs average rewards'][49]
av_df_edecay_sig1_eps3_d90 = df_edecay_sig1_eps3_d90['total runs average rewards'][49]

# %%
cum_df_random_sig1 = df_random_sig1['total runs cum rewards'][50]
cum_df_baseline_sig1_eps1 = df_baseline_sig1_eps1['total runs cum rewards'][49]
cum_df_baseline_sig1_eps2 = df_baseline_sig1_eps2['total runs cum rewards'][49]
cum_df_baseline_sig1_eps3 = df_baseline_sig1_eps3['total runs cum rewards'][49]
cum_df_egreedy_sig1_eps1 = df_egreedy_sig1_eps1['total runs cum rewards'][49]
cum_df_egreedy_sig1_eps2 = df_egreedy_sig1_eps2['total runs cum rewards'][49]
cum_df_egreedy_sig1_eps3 = df_egreedy_sig1_eps3['total runs cum rewards'][49]
cum_df_edecay_sig1_eps1_d99 = df_edecay_sig1_eps1_d99['total runs cum rewards'][49]
cum_df_edecay_sig1_eps1_d95 = df_edecay_sig1_eps1_d95['total runs cum rewards'][49]
cum_df_edecay_sig1_eps1_d90 = df_edecay_sig1_eps1_d90['total runs cum rewards'][49]
cum_df_edecay_sig1_eps2_d99 = df_edecay_sig1_eps2_d99['total runs cum rewards'][49]
cum_df_edecay_sig1_eps2_d95 = df_edecay_sig1_eps2_d95['total runs cum rewards'][49]
cum_df_edecay_sig1_eps2_d90 = df_edecay_sig1_eps2_d90['total runs cum rewards'][49]
cum_df_edecay_sig1_eps3_d99 = df_edecay_sig1_eps3_d99['total runs cum rewards'][49]
cum_df_edecay_sig1_eps3_d95 = df_edecay_sig1_eps3_d95['total runs cum rewards'][49]
cum_df_edecay_sig1_eps3_d90 = df_edecay_sig1_eps3_d90['total runs cum rewards'][49]

# %%
av_sig_1 = {"df_random_sig1":av_df_random_sig1,
        "df_baseline_sig1_eps1":av_df_baseline_sig1_eps1,
       "df_baseline_sig1_eps2":av_df_baseline_sig1_eps2,
       "df_baseline_sig1_eps3":av_df_baseline_sig1_eps3,
       "df_egreedy_sig1_eps1":av_df_egreedy_sig1_eps1,
       "df_egreedy_sig1_eps2":av_df_egreedy_sig1_eps2,
       "df_egreedy_sig1_eps3":av_df_egreedy_sig1_eps3,
       "df_edecay_sig1_eps1_d99":av_df_edecay_sig1_eps1_d99,
       "df_edecay_sig1_eps1_d95":av_df_edecay_sig1_eps1_d95,
       "df_edecay_sig1_eps1_d90":av_df_edecay_sig1_eps1_d90,
       "df_edecay_sig1_eps2_d99":av_df_edecay_sig1_eps2_d99,
       "df_edecay_sig1_eps2_d95":av_df_edecay_sig1_eps2_d95,
       "df_edecay_sig1_eps2_d90":av_df_edecay_sig1_eps2_d90,
       "df_edecay_sig1_eps3_d99":av_df_edecay_sig1_eps3_d99,
       "df_edecay_sig1_eps3_d95":av_df_edecay_sig1_eps3_d95,
       "df_edecay_sig1_eps3_d90":av_df_edecay_sig1_eps3_d90}

# %%
average_sig1 = pd.DataFrame({'Model': list(av_sig_1.keys()), 'Average': list(av_sig_1.values())})

# %%
cum_sig_1 = {"df_random_sig1":cum_df_random_sig1,
        "df_baseline_sig1_eps1":cum_df_baseline_sig1_eps1,
       "df_baseline_sig1_eps2":cum_df_baseline_sig1_eps2,
       "df_baseline_sig1_eps3":cum_df_baseline_sig1_eps3,
       "df_egreedy_sig1_eps1":cum_df_egreedy_sig1_eps1,
       "df_egreedy_sig1_eps2":cum_df_egreedy_sig1_eps2,
       "df_egreedy_sig1_eps3":cum_df_egreedy_sig1_eps3,
       "df_edecay_sig1_eps1_d99":cum_df_edecay_sig1_eps1_d99,
       "df_edecay_sig1_eps1_d95":cum_df_edecay_sig1_eps1_d95,
       "df_edecay_sig1_eps1_d90":cum_df_edecay_sig1_eps1_d90,
       "df_edecay_sig1_eps2_d99":cum_df_edecay_sig1_eps2_d99,
       "df_edecay_sig1_eps2_d95":cum_df_edecay_sig1_eps2_d95,
       "df_edecay_sig1_eps2_d90":cum_df_edecay_sig1_eps2_d90,
       "df_edecay_sig1_eps3_d99":cum_df_edecay_sig1_eps3_d99,
       "df_edecay_sig1_eps3_d95":cum_df_edecay_sig1_eps3_d95,
       "df_edecay_sig1_eps3_d90":cum_df_edecay_sig1_eps3_d90}

# %%
cumul_sig1 = pd.DataFrame({'Model': list(cum_sig_1.keys()), 'Cum': list(cum_sig_1.values())})

# %%
sig1 = average_sig1.merge(cumul_sig1,on='Model')

# %%
sig1
# Out:
#                       Model   Average      Cum
# 0            df_random_sig1  0.059289  2.96447
# 1     df_baseline_sig1_eps1  0.061737  3.08687
# 2     df_baseline_sig1_eps2  0.062012  3.10059
# 3     df_baseline_sig1_eps3  0.062029  3.10144
# 4      df_egreedy_sig1_eps1  0.064970  3.24848
# 5      df_egreedy_sig1_eps2  0.064640  3.23200
# 6      df_egreedy_sig1_eps3  0.064042  3.20211
# 7   df_edecay_sig1_eps1_d99  0.065192  3.25961
# 8   df_edecay_sig1_eps1_d95  0.062504  3.12519
# 9   df_edecay_sig1_eps1_d90  0.067049  3.35246
# 10  df_edecay_sig1_eps2_d99  0.065430  3.27149
# 11  df_edecay_sig1_eps2_d95  0.065928  3.29639
# 12  df_edecay_sig1_eps2_d90  0.065307  3.26534
# 13  df_edecay_sig1_eps3_d99  0.063753  3.18763
# 14  df_edecay_sig1_eps3_d95  0.065196  3.25979
# 15  df_edecay_sig1_eps3_d90  0.063255  3.16275

# %%
sig1.to_csv('SIG1.csv')
